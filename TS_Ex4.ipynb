# %%
from pandas import read_csv
from pandas import datetime
from matplotlib import pyplot
from pandas.plotting import autocorrelation_plot
from pandas import DataFrame
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_process import ArmaProcess
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
# %matplotlib inline
plt.rcParams['figure.figsize'] = [10, 7.5]

# %%
train = pd.read_csv('Ex4.csv')

# %%
train['date'] = pd.to_datetime(train['date'], format='%d-%m-%Y')
train['Year'] = train['date'].dt.year
train['Values'] = train['open'].values.round().astype(int)

# %%
train.head()
# Out:
#         date   open  Year  Values
# 0 2013-02-08  15.07  2013      15
# 1 2013-02-11  14.89  2013      15
# 2 2013-02-12  14.45  2013      14
# 3 2013-02-13  14.30  2013      14
# 4 2013-02-14  14.94  2013      15

# %%
ar1 = train['Year'].values.reshape(-1, 1)
ma1 = train['Values'].values.reshape(-1, 1)

# %%
ARMA_1 = ArmaProcess(ar1,ma1).generate_sample(nsample = 1000)
plt.plot(ARMA_1)
plt.title('Simulated ARMA(1,1) Process')
plt.xlim([0, 200])
plt.show()
plot_acf(ARMA_1)
plot_pacf(ARMA_1)
ar2 = train['Year']
ma2 = train['Values']
ARMA_2 = ArmaProcess(ar2, ma2).generate_sample(nsample=10000)
plt.plot(ARMA_2)
plt.title('Simulated ARMA(2,2) Process')
plt.xlim([0, 50])
plt.show()
plot_acf(ARMA_2)
plot_pacf(ARMA_2)
